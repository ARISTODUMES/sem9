# %%
from keras.datasets import imdb
from keras import layers
from keras import models
from keras import optimizers
from keras.preprocessing.text import Tokenizer
import numpy as np

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=1000)

tokenizer = Tokenizer(num_words=1000)
x_train = tokenizer.sequences_to_matrix(train_data, mode='binary')
x_test = tokenizer.sequences_to_matrix(test_data, mode='binary')

y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(1000,)))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer=optimizers.RMSprop(lr=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    epochs=10,
                    batch_size=128,
                    validation_split=0.2)

test_loss, test_acc = model.evaluate(x_test, y_test)

print('Test accuracy:', test_acc)
# Out:
# Epoch 1/10
# 157/157 [==============================] - 6s 14ms/step - loss: 0.4547 - accuracy: 0.8007 - val_loss: 0.3728 - val_accuracy: 0.8410
# Epoch 2/10
# 157/157 [==============================] - 1s 9ms/step - loss: 0.3322 - accuracy: 0.8604 - val_loss: 0.3282 - val_accuracy: 0.8638
# Epoch 3/10
# 157/157 [==============================] - 1s 9ms/step - loss: 0.3130 - accuracy: 0.8689 - val_loss: 0.3273 - val_accuracy: 0.8636
# Epoch 4/10
# 157/157 [==============================] - 1s 9ms/step - loss: 0.3073 - accuracy: 0.8729 - val_loss: 0.3443 - val_accuracy: 0.8558
# Epoch 5/10
# 157/157 [==============================] - 2s 10ms/step - loss: 0.3054 - accuracy: 0.8726 - val_loss: 0.3336 - val_accuracy: 0.8614
# Epoch 6/10
# 157/157 [==============================] - 2s 10ms/step - loss: 0.3028 - accuracy: 0.8730 - val_loss: 0.3362 - val_accuracy: 0.8620
# Epoch 7/10
# 157/157 [==============================] - 1s 9ms/step - loss: 0.3008 - accuracy: 0.8747 - val_loss: 0.3319 - val_accuracy: 0.8622
# Epoch 8/10
# 157/157 [==============================] - 2s 10ms/step - loss: 0.2982 - accuracy: 0.8767 - val_loss: 0.3320 - val_accuracy: 0.8622
# Epoch 9/10
# 157/157 [==============================] - 1s 9ms/step - loss: 0.2959 - accuracy: 0.8787 - val_loss: 0.3371 - val_accuracy: 0.8596
# Epoch 10/10
# 157/157 [==============================] - 1s 9ms/step - loss: 0.2921 - accuracy: 0.8802 - val_loss: 0.3353 - val_accuracy: 0.8596
# 782/782 [==============================] - 5s 6ms/step - loss: 0.3378 - accuracy: 0.8555
# Test accuracy: 0.8555200099945068

# %%
from keras.datasets import imdb
from keras import layers
from keras import models
from keras import optimizers
from keras.preprocessing.text import Tokenizer
import numpy as np
import matplotlib.pyplot as plt

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=1000)

tokenizer = Tokenizer(num_words=1000)
x_train = tokenizer.sequences_to_matrix(train_data, mode='binary')
x_test = tokenizer.sequences_to_matrix(test_data, mode='binary')

y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(1000,)))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer=optimizers.RMSprop(lr=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    epochs=10,
                    batch_size=128,
                    validation_split=0.2)

test_loss, test_acc = model.evaluate(x_test, y_test)

print('Test accuracy:', test_acc)

# Plotting the training and validation accuracy
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# Plotting the training and validation loss
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Epoch 1/10
# 157/157 [==============================] - 6s 15ms/step - loss: 0.4423 - accuracy: 0.8064 - val_loss: 0.3825 - val_accuracy: 0.8336
# Epoch 2/10
# 157/157 [==============================] - 2s 10ms/step - loss: 0.3294 - accuracy: 0.8611 - val_loss: 0.3335 - val_accuracy: 0.8622
# Epoch 3/10
# 157/157 [==============================] - 2s 13ms/step - loss: 0.3137 - accuracy: 0.8695 - val_loss: 0.3304 - val_accuracy: 0.8614
# Epoch 4/10
# 157/157 [==============================] - 2s 13ms/step - loss: 0.3085 - accuracy: 0.8716 - val_loss: 0.3302 - val_accuracy: 0.8636
# Epoch 5/10
# 157/157 [==============================] - 2s 13ms/step - loss: 0.3074 - accuracy: 0.8713 - val_loss: 0.3313 - val_accuracy: 0.8632
# Epoch 6/10
# 157/157 [==============================] - 1s 10ms/step - loss: 0.3047 - accuracy: 0.8748 - val_loss: 0.3388 - val_accuracy: 0.8600
# Epoch 7/10
# 157/157 [==============================] - 2s 10ms/step - loss: 0.3041 - accuracy: 0.8741 - val_loss: 0.3338 - val_accuracy: 0.8642
# Epoch 8/10
# 157/157 [==============================] - 2s 12ms/step - loss: 0.3025 - accuracy: 0.8752 - val_loss: 0.3391 - val_accuracy: 0.8600
# Epoch 9/10
# 157/157 [==============================] - 2s 10ms/step - loss: 0.3014 - accuracy: 0.8748 - val_loss: 0.3344 - val_accuracy: 0.8614
# Epoch 10/10
# 157/157 [==============================] - 1s 9ms/step - loss: 0.2975 - accuracy: 0.8748 - val_loss: 0.3348 - val_accuracy: 0.8644
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3372 - accuracy: 0.8568
# Test accuracy: 0.8568400144577026
